# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import  LabelBinarizer
from sklearn_pandas import DataFrameMapper
from sklearn.base import TransformerMixin

# %%
raw_data = pd.read_csv('inputfile.csv', encoding= 'latin-1 ')
raw_data["width"]= raw_data.width.str.replace('+', '')
features = ['price', 'numshows', 'width','medium', 'instit']
df = raw_data[features]
df = df.iloc[:1000,:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-21b2bad0c08a> in <module>()
#       1 raw_data = pd.read_csv('inputfile.csv', encoding= 'latin-1 ')
# ----> 2 raw_data["width"]= raw_data.width.str.replace('+', '')
#       3 features = ['price', 'numshows', 'width','medium', 'instit']
#       4 df = raw_data[features]
#       5 df = df.iloc[:1000,:]
#
# ~/Desktop/anaconda/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'width'

# %%
raw_data = pd.read_csv('inputfile.csv', encoding= 'latin-1 ')
raw_data
# Out:
#        Unnamed: 0               artist  years_active  numshows  \
# 0               0          andy_warhol        1928.0      3971
# 1               2          andy_warhol        1928.0      3971
# 2               3          andy_warhol        1928.0      3971
# 3               5          andy_warhol        1928.0      3971
# 4               6          andy_warhol        1928.0      3971
# 5               8          andy_warhol        1928.0      3971
# 6              10          andy_warhol        1928.0      3971
# 7              12          andy_warhol        1928.0      3971
# 8              13          andy_warhol        1928.0      3971
# 9              14          andy_warhol        1928.0      3971
# 10             15          andy_warhol        1928.0      3971
# 11             16          andy_warhol        1928.0      3971
# 12             17          andy_warhol        1928.0      3971
# 13             18          andy_warhol        1928.0      3971
# ...

# %%
features = ['price', 'numshows', 'width','medium', 'instit']
df = raw_data[features]
df = df.iloc[:1000,:]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-24aafc042cee> in <module>()
#       1 features = ['price', 'numshows', 'width','medium', 'instit']
# ----> 2 df = raw_data[features]
#       3 df = df.iloc[:1000,:]
#       4 df
#
# ~/Desktop/anaconda/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/Desktop/anaconda/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# ...

# %%
features = ['price', 'numshows', 'dimension','medium', 'instit']
df = raw_data[features]
df = df.iloc[:1000,:]
df
# Out:
#      price  numshows dimension            medium  \
# 0    37000      3971      1;12          painting
# 1    49000      3971      1;12          painting
# 2    39000      3971     13;30          painting
# 3    49000      3971     13;30          painting
# 4    49000      3971     13;30          painting
# 5    29000      3971       31+          painting
# 6    39000      3971       31+          painting
# 7    49000      3971       31+          painting
# 8    49000      3971       31+          painting
# 9    49000      3971       31+          painting
# 10   49000      3971       31+          painting
# 11   49000      3971       31+          painting
# 12   49000      3971       31+          painting
# 13   49000      3971       31+          painting
# 14   49000      3971       31+          painting
# 15   49000      3971       31+          painting
# 16    1000      3971      1;12  prints_multiples
# 17    1000      3971      1;12  prints_multiples
# ...

# %%
def model():
        # create model
        model = Sequential()
        model.add(Dense(54, input_dim=3006, kernel_initializer='normal', activation='relu'))
        model.add(Dense(9, kernel_initializer='normal', activation='relu'))
        model.add(Dense(2, kernel_initializer='normal', activation='relu'))
        model.add(Dense(1, kernel_initializer='normal'))
        # Compile model
        model.compile(loss='mean_squared_error', optimizer='adam')
        return model

# %%
class DenseTransformer(TransformerMixin):
    def transform(self, X, y=None, **fit_params):
        return X.todense()
    def fit_transform(self, X, y=None, **fit_params):
        self.fit(X, y, **fit_params)
        return self.transform(X)
    def fit(self, X, y=None, **fit_params):
        return self  


pipeline = Pipeline([
    ('mapper', DataFrameMapper([
                    #('artist', LabelBinarizer()),
                    ('numshows', None),
                    ('dimension', None),
                    ('medium', LabelBinarizer()),
                    ('instit', Pipeline([
                        ('instit', CountVectorizer(max_features = 3000)),
                        ('transformer', DenseTransformer())]))
                    ]))
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-897acf4129d1> in <module>()
# ----> 1 class DenseTransformer(TransformerMixin):
#       2     def transform(self, X, y=None, **fit_params):
#       3         return X.todense()
#       4     def fit_transform(self, X, y=None, **fit_params):
#       5         self.fit(X, y, **fit_params)
#
# NameError: name 'TransformerMixin' is not defined

# %%
X = pipeline.fit_transform(X1)
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a7212342bc4b> in <module>()
# ----> 1 X = pipeline.fit_transform(X1)
#       2 X.shape
#
# NameError: name 'pipeline' is not defined

# %%
Y= df.price.values
X1= df[df.columns.drop(['price'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-acd679949108> in <module>()
# ----> 1 Y= df.price.values
#       2 X1= df[df.columns.drop(['price'])]
#
# NameError: name 'df' is not defined

# %%
X = pipeline.fit_transform(X1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d8714b4ced6a> in <module>()
# ----> 1 X = pipeline.fit_transform(X1)
#
# NameError: name 'pipeline' is not defined

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-253bcac7dd80> in <module>()
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
seed = 7
numpy.random.seed(seed)
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ac50bf420536> in <module>()
#       1 seed = 7
# ----> 2 numpy.random.seed(seed)
#       3 # evaluate model with standardized dataset
#       4 estimators = []
#       5 estimators.append(('standardize', StandardScaler()))
#
# NameError: name 'numpy' is not defined

# %%
seed = 7
np.random.seed(seed)
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ef22eda9f682> in <module>()
#       1 seed = 7
# ----> 2 np.random.seed(seed)
#       3 # evaluate model with standardized dataset
#       4 estimators = []
#       5 estimators.append(('standardize', StandardScaler()))
#
# NameError: name 'np' is not defined

# %%
pipeline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4a07924977a8> in <module>()
# ----> 1 pipeline
#
# NameError: name 'pipeline' is not defined

# %%
estimators
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d77f010a1bda> in <module>()
# ----> 1 estimators
#
# NameError: name 'estimators' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0a7959c28144> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimator, X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimators, X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5c260f4d32e8> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimators, X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
seed = 7
numpy.random.seed(seed)
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ac50bf420536> in <module>()
#       1 seed = 7
# ----> 2 numpy.random.seed(seed)
#       3 # evaluate model with standardized dataset
#       4 estimators = []
#       5 estimators.append(('standardize', StandardScaler()))
#
# NameError: name 'numpy' is not defined

# %%
seed = 7
np.random.seed(seed)
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ef22eda9f682> in <module>()
#       1 seed = 7
# ----> 2 np.random.seed(seed)
#       3 # evaluate model with standardized dataset
#       4 estimators = []
#       5 estimators.append(('standardize', StandardScaler()))
#
# NameError: name 'np' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimators, X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5c260f4d32e8> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimators, X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0a7959c28144> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimator, X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator[0], X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f82d8e9c425e> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimator[0], X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimators[0], X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-97edfe77b19f> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimators[0], X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
seed = 7
np.random.seed(seed)
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ef22eda9f682> in <module>()
#       1 seed = 7
# ----> 2 np.random.seed(seed)
#       3 # evaluate model with standardized dataset
#       4 estimators = []
#       5 estimators.append(('standardize', StandardScaler()))
#
# NameError: name 'np' is not defined

# %%
estimators[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-16a6f871e343> in <module>()
# ----> 1 estimators[0]
#
# NameError: name 'estimators' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator[0], X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f82d8e9c425e> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimator[0], X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimators[0], X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-97edfe77b19f> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimators[0], X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d4659e536154> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#
# NameError: name 'KFold' is not defined

# %%
kfold
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-48dcad69e295> in <module>()
# ----> 1 kfold
#
# NameError: name 'kfold' is not defined

# %%
results = cross_val_score(lasso, X, Y, cv=kfold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-f3877434178f> in <module>()
# ----> 1 results = cross_val_score(lasso, X, Y, cv=kfold)
#
# NameError: name 'cross_val_score' is not defined

# %%
lasso = linear_model.Lasso()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-dfefd4de03aa> in <module>()
# ----> 1 lasso = linear_model.Lasso()
#
# NameError: name 'linear_model' is not defined

# %%
scaler = StandardScaler()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a80baa4053ad> in <module>()
# ----> 1 scaler = StandardScaler()
#
# NameError: name 'StandardScaler' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(scaler, X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-eef92a8975e1> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(scaler, X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(scaler, X, Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-505bb1243c01> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(scaler, X, Y)
#
# NameError: name 'KFold' is not defined

# %%
pipeline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4a07924977a8> in <module>()
# ----> 1 pipeline
#
# NameError: name 'pipeline' is not defined

# %%
results = cross_val_score(pipeline, X, Y, cv=kfold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-0db6c2c6b3d6> in <module>()
# ----> 1 results = cross_val_score(pipeline, X, Y, cv=kfold)
#
# NameError: name 'cross_val_score' is not defined

# %%
pipeline[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ae4b68ea6e6c> in <module>()
# ----> 1 pipeline[0]
#
# NameError: name 'pipeline' is not defined

# %%
pipeline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-4a07924977a8> in <module>()
# ----> 1 pipeline
#
# NameError: name 'pipeline' is not defined

# %%
KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0))
# Out:
#   File "<ipython-input-35-a388f527ef1b>", line 1
#     KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0))
#                                                                       ^
# SyntaxError: invalid syntax

# %%
KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-848cf3a6943c> in <module>()
# ----> 1 KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0)
#
# NameError: name 'KerasRegressor' is not defined

# %%
results = cross_val_score(KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0), X, Y, cv=kfold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-15ddbe46706b> in <module>()
# ----> 1 results = cross_val_score(KerasRegressor(build_fn=model, epochs=50, batch_size=5, verbose=0), X, Y, cv=kfold)
#
# NameError: name 'cross_val_score' is not defined

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=5, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-ce1fb10e9440> in <module>()
#       1 # fix random seed for reproducibility
#       2 seed = 7
# ----> 3 numpy.random.seed(seed)
#       4 # evaluate model with standardized dataset
#       5 estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=5, verbose=0)
#
# NameError: name 'numpy' is not defined

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=model, nb_epoch=100, batch_size=5, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-71bc15e78c80> in <module>()
#       1 # fix random seed for reproducibility
#       2 seed = 7
# ----> 3 np.random.seed(seed)
#       4 # evaluate model with standardized dataset
#       5 estimator = KerasRegressor(build_fn=model, nb_epoch=100, batch_size=5, verbose=0)
#
# NameError: name 'np' is not defined

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=5, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-ce1fb10e9440> in <module>()
#       1 # fix random seed for reproducibility
#       2 seed = 7
# ----> 3 numpy.random.seed(seed)
#       4 # evaluate model with standardized dataset
#       5 estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=5, verbose=0)
#
# NameError: name 'numpy' is not defined

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=5, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-2b8ec01fdb86> in <module>()
#       1 # fix random seed for reproducibility
#       2 seed = 7
# ----> 3 np.random.seed(seed)
#       4 # evaluate model with standardized dataset
#       5 estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=5, verbose=0)
#
# NameError: name 'np' is not defined

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=model, nb_epoch=100, batch_size=5, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-71bc15e78c80> in <module>()
#       1 # fix random seed for reproducibility
#       2 seed = 7
# ----> 3 np.random.seed(seed)
#       4 # evaluate model with standardized dataset
#       5 estimator = KerasRegressor(build_fn=model, nb_epoch=100, batch_size=5, verbose=0)
#
# NameError: name 'np' is not defined

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-0a7959c28144> in <module>()
# ----> 1 kfold = KFold(n_splits=10, random_state=seed)
#       2 results = cross_val_score(estimator, X, Y, cv=kfold)
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# NameError: name 'KFold' is not defined

# %%
score = model.evaluate(X, Y,verbose=1)

print(score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-c330246825d0> in <module>()
# ----> 1 score = model.evaluate(X, Y,verbose=1)
#       2
#       3 print(score)
#
# AttributeError: 'function' object has no attribute 'evaluate'

# %%
model = model()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-612025cf5234> in <module>()
# ----> 1 model = model()
#
# <ipython-input-2-4b928cbb2017> in model()
#       1 def model():
#       2         # create model
# ----> 3         model = Sequential()
#       4         model.add(Dense(54, input_dim=3006, kernel_initializer='normal', activation='relu'))
#       5         model.add(Dense(9, kernel_initializer='normal', activation='relu'))
#
# NameError: name 'Sequential' is not defined
